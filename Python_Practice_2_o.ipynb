# %% [markdown]
# <a href="https://colab.research.google.com/github/Pankaj-2003/General_python_practice/blob/main/Python_Practice_2_o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Questions**

# %%
class Foo:
    def __init__(self, a, b, c):
        # ...
        pass

x = Foo(1, 2, 3) # __init__

#The __call__ implements function call operator.

class Foo:
    def __call__(self, a, b, c):
        # ...
        pass

x = Foo()
x(1, 2, 3) # __call__

# %% [markdown]
# # inheritance

# %%
class A:
  def __init__(self):
    print(f"world")

class B(A):
  def __init__(self):
    print(f"hello")
    super().__init__()

# %%
a = B()
# Out:
# hello
# world

# %% [markdown]
# # abstraction

# %%
class Payment:
  def Pay(self):
    pass

class Paypal(Payment):
  def Pay(self):
    print(f"paid using Paypal")

class CreditCard(Payment):
  def Pay(self):
    print(f"paid using creditcard")

# %%
method = Paypal()

method.Pay()
# Out:
# paid using Paypal

# %% [markdown]
# # encapsulation

# %%
class Account:
  def __init__(self , balance):
    self.__balance = balance

  def show_balance(self):
    return self.__balance

class Transaction(Account):

  def deposit(self , amount):
    print(f"{amount} deposited")
    self._Account__balance += amount

  def withdrawl(self, amount):
    print(f"{amount} withdrawl")
    self._Account__balance -= amount

# %%
tran = Transaction(70000)

# %%
tran.deposit(1)
# Out:
# 1 deposited

# %%
tran.show_balance()
# Out:
# 70001

# %% [markdown]
# # poly

# %%
class Animal:
  def speak(self):
    print("i am a animal i can speak")
class Dog(Animal):
  def speak(self):
    print("i am a dog i can bark")

# %%
a = Animal()

b= Dog()

# %%
a.speak()

b.speak()
# Out:
# i am a animal i can speak
# i am a dog i can bark

# %% [markdown]
# # **Neural net**

# %%
nn.sequential(nn.flatten()

nn.linear(784 , 128)  # w = (128 , 784)

nn.relu()

nn.linear(128 , 64)

nn.relu()

nn.linear(64 , 10)
)
.compile()

# %% [markdown]
# # **CNNs**

# %%
nn.sequential(
    nn.conv2d(1 , 32 , kernel_size = 3 , stride = 1 , padding = 1)
    nn.Relu()
    nn.MaxPool2d(kernel_size = 2 , stride = 1)

    nn.conv2d(32 , 64 , kernel_size = 3 , stride = 1 , padding = 1)
    nn.Relu()
    nn.MaxPool2d(kernel_size = 2 , stride = 1)

    nn.flatten()
    nn.linear( output , 128)
    nn.Relu()
    nn.linear(128  , 10)

)

# %%
def reverse_number(n):
    rev = 0

    while n > 0:
        rev = rev * 10 + n % 10
        n //= 10

    return rev

num = 12345
print(reverse_number(num))
# Out:
# Reversed Number: 54321

# %%
str1 = "pankajtiwari"

str2 = "tupaac"

# %%
count = 0
track = []
for i in str2:
  if i in str1 and i not in track:
    count +=1
    track.append(i)

# %%
count
# Out:
# 3
